# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_daun.csv')

# %%
df = pd.read_csv('dataset_daun.csv')

print("Jumlah baris sebelum pembersihan:", len(df))

df = df.dropna(subset=['contrast', 'correlation', 'energy', 'homogeneity', 'kondisi'])

df[['contrast', 'correlation', 'energy', 'homogeneity']] = df[['contrast', 'correlation', 'energy', 'homogeneity']].apply(pd.to_numeric, errors='coerce')

df = df.dropna(subset=['contrast', 'correlation', 'energy', 'homogeneity'])

print("Jumlah baris setelah pembersihan:", len(df))
print("Distribusi label:")
print(df['kondisi'].value_counts())
# Out:
# Jumlah baris sebelum pembersihan: 300
# Jumlah baris setelah pembersihan: 300
# Distribusi label:
# kondisi
# sehat          150
# tidak sehat    150
# Name: count, dtype: int64

# %%
import cv2
import matplotlib.pyplot as plt
import os

base_dir = "dataset"

image_paths = []
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_paths.append(os.path.join(root, file))

# Ambil 10 gambar pertama
image_paths = sorted(image_paths)[:10]

plt.figure(figsize=(12, 6))

for i, path in enumerate(image_paths):
    img = cv2.imread(path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    plt.subplot(2, 5, i + 1)
    plt.imshow(gray, cmap='gray')
    plt.title(f'Gambar {i+1}')
    plt.axis('off')

plt.tight_layout()
plt.show()
